# %%
import urllib.request
import json
import datetime
import time
import re
import pandas as pd

country_code = 'vn'


def get_json_product(itemid, limit, offset, shopid, type=0):
    '''Get JSON of a product
    * type = 0: get all ratings
    * type = 1..5: get ratings based on rating stars
    * country_code = 'vn' or 'sg'
    '''
    url = 'https://shopee.{}/api/v2/item/get_ratings?filter=0&flag=1&itemid={}&limit={}&offset={}&shopid={}&type={}'.format(
        country_code, itemid, limit, offset, shopid, type)
    response = urllib.request.urlopen(url)
    data = json.loads(response.read())
    return data


def get_json_recommend(limit, offset):
    url = 'https://shopee.{}/api/v4/recommend/recommend?bundle=daily_discover_main&limit={}&offset={}'.format(
        country_code, limit, offset)
    response = urllib.request.urlopen(url)
    data = json.loads(response.read())
    return data


def get_json_campaign(label, limit, offset):
    url = 'https://shopee.{}/api/v4/recommend/recommend?bundle=daily_discover_campaign&label={}&limit={}&offset={}'.format(
        country_code, label, limit, offset)
    response = urllib.request.urlopen(url)
    data = json.loads(response.read())
    return data


def remove_adjacent_duplicates(str):
    return re.sub(r'(.)\1+', r'\1\1', str)


def format_string(str):
    if str:
        locale_chars = ''
        if country_code == 'vn':
            locale_chars = ' ,.\n\tABCDEGHIKLMNOPQRSTUVXYabcdeghiklmnopqrstuvxyÀÁÂÃÈÉÊÌÍÒÓÔÕÙÚÝàáâãèéêìíòóôõùúýĂăĐđĨĩŨũƠơƯưẠạẢảẤấẦầẨẩẪẫẬậẮắẰằẲẳẴẵẶặẸẹẺẻẼẽẾếỀềỂểỄễỆệỈỉỊịỌọỎỏỐốỒồỔổỖỗỘộỚớỜờỞởỠỡỢợỤụỦủỨứỪừỬửỮữỰựỲỳỴỵỶỷỸỹ'
        elif country_code == 'sg':
            locale_chars = ' ,.\n\tABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
        bad_chars = [('\t', ', '), ('\n', '. '), ('  ', ' '), (' .', '.'),
                     (' ,', ','), ('..', '.'), (',,', ','), (',.', '.'), ('.,', ',')]
        # Keep only specific characters
        str = ''.join(c for c in str if c in locale_chars)
        str = remove_adjacent_duplicates(str)
        for c in bad_chars:
            str = str.replace(c[0], c[1])
        str = str.strip()
    return str


def get_ratings_from_json(json_data, min_len_str=4):
    data = json_data['data']
    ratings = data['ratings'] if data != None else None
    result = []
    if ratings != None:
        for r in ratings:
            itemid = r['itemid']
            shopid = r['shopid']
            userid = r['userid']
            cmtid = r['cmtid']
            mtime = datetime.datetime.fromtimestamp(
                r['mtime']).strftime('%d-%m-%Y %H:%M:%S')
            rating_star = r['rating_star']
            comment = format_string(r['comment'])
            if comment != None and len(comment) >= min_len_str:
                result.append(
                    {
                        'itemid': itemid,
                        'shopid': shopid,
                        'userid': userid,
                        'cmtid': cmtid,
                        'mtime': mtime,
                        'rating_star': rating_star,
                        'comment': comment
                    })
    return result


def get_products_from_json(json_data, get_top_product=False):
    data = json_data['data']
    sections = data['sections'] if data != None else []
    result = []
    for s in sections:
        data = s['data']
        item = data['item']
        if item != None:
            for i in item:
                shopid = i['shopid']
                itemid = i['itemid']
                result.append(
                    {
                        'shopid': shopid,
                        'itemid': itemid
                    })
        if get_top_product:
            top_product = data['top_product']
            if top_product != None:
                for t in top_product:
                    list = t['list']
                    data = list['data']
                    item_lite = data['item_lite']
                    if item_lite != None:
                        for i in item_lite:
                            shopid = i['shopid']
                            itemid = i['itemid']
                            result.append(
                                {
                                    'shopid': shopid,
                                    'itemid': itemid
                                })
    return result


def get_all_ratings(itemid, shopid, limit=6, offset=0, min_len_cmt=4, type=0):
    result = []
    while True:
        json_data = get_json_product(itemid, limit, offset, shopid, type)
        ratings = get_ratings_from_json(json_data, min_len_cmt)
        if ratings == []:
            break
        else:
            result += ratings
        offset += limit
    return result


def get_all_recommended_products(max_products=100, limit=10, offset=0, get_top_product=False):
    result = []
    if max_products < limit:
        limit = max_products
    while True:
        start_time = time.time()
        # Notes: The number of products may be smaller than limit number although max_products < limit
        # So the number of result can be larger than the max_products
        json_data = get_json_recommend(limit, offset)
        products = get_products_from_json(json_data, get_top_product)
        if products == [] or len(result) >= max_products:
            break
        else:
            result += products
            print('Đã lấy về {} sản phẩm trên tổng số tối đa {} sản phẩm. Mất {:0.2f} mili giây'.format(
                len(result), max_products, (time.time() - start_time)*1000))
        offset += limit
    return result


def get_all_campaign_products(label, max_products=100, limit=10, offset=0):
    result = []
    if max_products < limit:
        limit = max_products
    while True:
        start_time = time.time()
        # Notes: The number of products may be smaller than limit number although max_products < limit
        # So the number of result can be larger than the max_products
        json_data = get_json_campaign(label, limit, offset)
        products = get_products_from_json(json_data, False)
        if products == [] or len(result) >= max_products:
            break
        else:
            result += products
            print('Đã lấy về {} sản phẩm trên tổng số {} sản phẩm, tối đa {} sản phẩm. Mất {:0.2f} mili giây'.format(
                len(products), len(result), max_products, (time.time() - start_time)*1000))
        offset += limit
    return result


def export_to_text_file(array_of_json, filename, only_header=False):
    f = open(filename, 'a+', encoding='utf-8')
    if only_header:
        f.write('userid\tcmtid\tmtime\trating_star\tcomment\n')
    else:
        for j in array_of_json:
            f.write('{}\t{}\t{}\t{}\t{}\n'.format(
                j['userid'], j['cmtid'], j['mtime'], j['rating_star'], j['comment']))
    f.close()
    
def export_to_csv(array_of_json, filename, only_header=False):
    df = pd.DataFrame(array_of_json)
    if only_header:
        df.to_csv(filename, header=True, index=False, mode='a', encoding='utf-8')
    else:
        df.to_csv(filename, header=False, index=False, mode='a', encoding='utf-8')


def collect_reviews_product(filename, max_products, min_len_cmt=4, types=[0]):
    '''Collect all reviews of products with specific rating_star
    * type = array [0]: get all rating_stars
    * type = array [1..5]: get only these rating_stars
    '''
    products = get_all_recommended_products(
        max_products=max_products, get_top_product=True)
    # products = get_all_campaign_products(1005922, max_products)
    length_products = len(products)
    export_to_text_file(None, filename, True)
    for p in products:
        start_time = time.time()
        itemid = p['itemid']
        shopid = p['shopid']
        ratings = []
        if types != None and types != []:
            for t in types:
                ratings += get_all_ratings(
                    itemid, shopid, min_len_cmt=min_len_cmt, type=t)
        else:
            ratings += get_all_ratings(itemid, shopid, min_len_cmt=min_len_cmt)
        
        export_to_csv(ratings, filename)
        length_products -= 1
        print('Đã thu thập và ghi {} đánh giá của sản phẩm {} tại shop {}. Còn {} sản phẩm nữa. Mất {:0.2f} mili giây'.format(
            len(ratings), itemid, shopid, length_products, (time.time() - start_time)*1000))


def remove_duplicate_column(filename, col_check):
    df = pd.read_csv(filename, delimiter='\t')
    print(df['rating_star'].value_counts().sort_index(ascending=True))
    df.drop_duplicates(col_check, inplace=True)
    print(df['rating_star'].value_counts().sort_index(ascending=True))
    df.to_csv(filename, sep='\t', index=False)


def prune(filename):
    df = pd.read_csv(filename, delimiter='\t')
    min = df.groupby('rating_star').agg('count')['comment'].min()
    for i in [1, 2, 3, 4, 5]:
        rows = df.loc[df['rating_star'] == i]
        rows = rows.sort_values(
            by='comment', key=lambda x: x.str.len(), ascending=False)
        rows = rows.head(min)
        header = True if i == 1 else False
        rows.to_csv('pruned_' + filename, mode='a',
                    index=False, sep='\t', header=header)

# %%
collect_reviews_product("reviews_45s.csv", max_products=500, min_len_cmt=4, types=[4, 5])
# Out:
# Đã lấy về 8 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 466.95 mili giây
# Đã lấy về 16 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 628.40 mili giây
# Đã lấy về 22 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 698.42 mili giây
# Đã lấy về 29 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 612.15 mili giây
# Đã lấy về 36 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 599.39 mili giây
# Đã lấy về 41 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 670.36 mili giây
# Đã lấy về 46 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 434.62 mili giây
# Đã lấy về 51 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 580.52 mili giây
# Đã lấy về 56 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 588.83 mili giây
# Đã lấy về 61 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 586.64 mili giây
# Đã lấy về 66 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 494.94 mili giây
# Đã lấy về 71 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 723.99 mili giây
# Đã lấy về 81 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 617.41 mili giây
# Đã lấy về 91 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 533.03 mili giây
# Đã lấy về 101 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 601.35 mili giây
# Đã lấy về 111 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 639.36 mili giây
# Đã lấy về 121 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 463.79 mili giây
# Đã lấy về 131 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 450.63 mili giây
# Đã lấy về 141 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 467.03 mili giây
# Đã lấy về 151 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 438.71 mili giây
# Đã lấy về 161 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 586.03 mili giây
# Đã lấy về 171 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 695.90 mili giây
# Đã lấy về 181 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 485.14 mili giây
# Đã lấy về 191 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 523.86 mili giây
# Đã lấy về 201 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 649.08 mili giây
# Đã lấy về 211 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 532.38 mili giây
# Đã lấy về 221 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 485.73 mili giây
# Đã lấy về 231 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 470.10 mili giây
# Đã lấy về 241 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 601.98 mili giây
# Đã lấy về 251 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 401.16 mili giây
# Đã lấy về 261 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 686.55 mili giây
# Đã lấy về 271 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 501.49 mili giây
# Đã lấy về 281 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 532.97 mili giây
# Đã lấy về 291 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 633.45 mili giây
# Đã lấy về 301 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 554.99 mili giây
# Đã lấy về 311 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 517.03 mili giây
# Đã lấy về 321 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 454.85 mili giây
# Đã lấy về 331 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 649.13 mili giây
# Đã lấy về 341 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 432.70 mili giây
# Đã lấy về 351 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 655.19 mili giây
# Đã lấy về 361 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 686.63 mili giây
# Đã lấy về 371 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 432.52 mili giây
# Đã lấy về 381 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 554.48 mili giây
# Đã lấy về 391 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 564.37 mili giây
# Đã lấy về 401 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 554.44 mili giây
# Đã lấy về 411 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 548.31 mili giây
# Đã lấy về 421 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 469.77 mili giây
# Đã lấy về 431 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 601.89 mili giây
# Đã lấy về 441 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 533.01 mili giây
# Đã lấy về 451 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 454.47 mili giây
# Đã lấy về 461 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 602.05 mili giây
# Đã lấy về 471 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 486.09 mili giây
# Đã lấy về 481 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 479.59 mili giây
# Đã lấy về 491 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 554.66 mili giây
# Đã lấy về 501 sản phẩm trên tổng số tối đa 500 sản phẩm. Mất 633.49 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 500 sản phẩm nữa. Mất 602.23 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 499 sản phẩm nữa. Mất 214958.12 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 498 sản phẩm nữa. Mất 1249.10 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 497 sản phẩm nữa. Mất 1092.03 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 496 sản phẩm nữa. Mất 3639.67 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 495 sản phẩm nữa. Mất 24120.85 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 494 sản phẩm nữa. Mất 670.74 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 493 sản phẩm nữa. Mất 654.29 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 492 sản phẩm nữa. Mất 586.13 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 491 sản phẩm nữa. Mất 1114.96 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 490 sản phẩm nữa. Mất 7032.05 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 489 sản phẩm nữa. Mất 1062.72 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 488 sản phẩm nữa. Mất 3090.63 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 487 sản phẩm nữa. Mất 21728.47 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 486 sản phẩm nữa. Mất 601.45 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 485 sản phẩm nữa. Mất 635.04 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 484 sản phẩm nữa. Mất 669.81 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 483 sản phẩm nữa. Mất 198966.51 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 482 sản phẩm nữa. Mất 1668.18 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 481 sản phẩm nữa. Mất 1732.81 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 480 sản phẩm nữa. Mất 6090.63 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 479 sản phẩm nữa. Mất 34742.40 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 478 sản phẩm nữa. Mất 570.56 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 477 sản phẩm nữa. Mất 218580.54 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 476 sản phẩm nữa. Mất 1140.64 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 475 sản phẩm nữa. Mất 1058.43 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 474 sản phẩm nữa. Mất 3754.28 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 473 sản phẩm nữa. Mất 21649.31 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 472 sản phẩm nữa. Mất 686.47 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 471 sản phẩm nữa. Mất 651.47 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 470 sản phẩm nữa. Mất 193706.71 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 469 sản phẩm nữa. Mất 1071.72 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 468 sản phẩm nữa. Mất 918.33 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 467 sản phẩm nữa. Mất 3618.94 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 466 sản phẩm nữa. Mất 22263.25 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 465 sản phẩm nữa. Mất 570.26 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 464 sản phẩm nữa. Mất 585.88 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 463 sản phẩm nữa. Mất 201709.26 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 462 sản phẩm nữa. Mất 3109.56 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 461 sản phẩm nữa. Mất 2656.38 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 460 sản phẩm nữa. Mất 6069.43 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 459 sản phẩm nữa. Mất 902.95 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 458 sản phẩm nữa. Mất 192603.52 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 457 sản phẩm nữa. Mất 1219.57 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 456 sản phẩm nữa. Mất 956.18 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 455 sản phẩm nữa. Mất 3505.04 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 454 sản phẩm nữa. Mất 585.82 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 453 sản phẩm nữa. Mất 217433.03 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 452 sản phẩm nữa. Mất 1071.81 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 451 sản phẩm nữa. Mất 1051.25 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 450 sản phẩm nữa. Mất 3537.21 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 449 sản phẩm nữa. Mất 579.55 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 448 sản phẩm nữa. Mất 1104.46 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 447 sản phẩm nữa. Mất 6583.98 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 446 sản phẩm nữa. Mất 941.50 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 445 sản phẩm nữa. Mất 3474.65 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 444 sản phẩm nữa. Mất 554.88 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 443 sản phẩm nữa. Mất 188587.54 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 442 sản phẩm nữa. Mất 1242.22 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 441 sản phẩm nữa. Mất 1061.98 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 440 sản phẩm nữa. Mất 3489.17 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 439 sản phẩm nữa. Mất 581.82 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 438 sản phẩm nữa. Mất 216583.01 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 437 sản phẩm nữa. Mất 1621.01 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 436 sản phẩm nữa. Mất 1685.04 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 435 sản phẩm nữa. Mất 5898.50 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 434 sản phẩm nữa. Mất 1038.37 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 433 sản phẩm nữa. Mất 200799.73 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 432 sản phẩm nữa. Mất 1040.56 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 431 sản phẩm nữa. Mất 1041.40 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 430 sản phẩm nữa. Mất 3301.08 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 429 sản phẩm nữa. Mất 645.28 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 428 sản phẩm nữa. Mất 194450.50 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 427 sản phẩm nữa. Mất 1050.37 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 426 sản phẩm nữa. Mất 854.83 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 425 sản phẩm nữa. Mất 3745.46 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 424 sản phẩm nữa. Mất 22413.54 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 423 sản phẩm nữa. Mất 655.20 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 422 sản phẩm nữa. Mất 549.89 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 421 sản phẩm nữa. Mất 31318.77 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 420 sản phẩm nữa. Mất 7808.82 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 419 sản phẩm nữa. Mất 517.21 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 418 sản phẩm nữa. Mất 206653.24 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 417 sản phẩm nữa. Mất 949.95 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 416 sản phẩm nữa. Mất 1143.56 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 415 sản phẩm nữa. Mất 3662.29 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 414 sản phẩm nữa. Mất 22158.09 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 413 sản phẩm nữa. Mất 655.68 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 412 sản phẩm nữa. Mất 674.47 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 411 sản phẩm nữa. Mất 30897.77 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 410 sản phẩm nữa. Mất 11578.99 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 409 sản phẩm nữa. Mất 617.24 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 408 sản phẩm nữa. Mất 205377.93 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 407 sản phẩm nữa. Mất 1103.77 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 406 sản phẩm nữa. Mất 963.46 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 405 sản phẩm nữa. Mất 3888.68 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 404 sản phẩm nữa. Mất 22162.72 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 403 sản phẩm nữa. Mất 583.71 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 402 sản phẩm nữa. Mất 631.79 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 401 sản phẩm nữa. Mất 30545.83 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 400 sản phẩm nữa. Mất 8011.67 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 399 sản phẩm nữa. Mất 648.08 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 398 sản phẩm nữa. Mất 189953.93 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 397 sản phẩm nữa. Mất 1179.23 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 396 sản phẩm nữa. Mất 1093.20 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 395 sản phẩm nữa. Mất 3593.47 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 394 sản phẩm nữa. Mất 22071.25 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 393 sản phẩm nữa. Mất 680.20 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 392 sản phẩm nữa. Mất 623.75 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 391 sản phẩm nữa. Mất 31629.12 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 390 sản phẩm nữa. Mất 8012.70 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 389 sản phẩm nữa. Mất 601.26 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 388 sản phẩm nữa. Mất 186904.04 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 387 sản phẩm nữa. Mất 1209.95 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 386 sản phẩm nữa. Mất 1062.36 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 385 sản phẩm nữa. Mất 3654.82 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 384 sản phẩm nữa. Mất 22078.34 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 383 sản phẩm nữa. Mất 686.28 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 382 sản phẩm nữa. Mất 560.67 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 381 sản phẩm nữa. Mất 31198.48 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 380 sản phẩm nữa. Mất 7662.89 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 379 sản phẩm nữa. Mất 546.71 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 378 sản phẩm nữa. Mất 1072.65 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 377 sản phẩm nữa. Mất 8050.32 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 376 sản phẩm nữa. Mất 1779.70 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 375 sản phẩm nữa. Mất 6111.74 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 374 sản phẩm nữa. Mất 34493.61 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 373 sản phẩm nữa. Mất 1856.14 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 372 sản phẩm nữa. Mất 903.32 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 371 sản phẩm nữa. Mất 41405.98 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 370 sản phẩm nữa. Mất 12450.31 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 369 sản phẩm nữa. Mất 918.62 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 368 sản phẩm nữa. Mất 196266.18 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 367 sản phẩm nữa. Mất 949.84 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 366 sản phẩm nữa. Mất 963.92 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 365 sản phẩm nữa. Mất 3325.06 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 364 sản phẩm nữa. Mất 22150.34 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 363 sản phẩm nữa. Mất 648.75 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 362 sản phẩm nữa. Mất 556.34 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 361 sản phẩm nữa. Mất 43128.27 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 360 sản phẩm nữa. Mất 12510.12 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 359 sản phẩm nữa. Mất 1018.54 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 358 sản phẩm nữa. Mất 227757.23 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 357 sản phẩm nữa. Mất 1024.63 mili giây
# Đã thu thập và ghi 7 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 356 sản phẩm nữa. Mất 1019.20 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 355 sản phẩm nữa. Mất 3642.80 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 354 sản phẩm nữa. Mất 22766.56 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 353 sản phẩm nữa. Mất 633.14 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 352 sản phẩm nữa. Mất 654.31 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 351 sản phẩm nữa. Mất 39338.06 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 350 sản phẩm nữa. Mất 12407.62 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 349 sản phẩm nữa. Mất 943.98 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 348 sản phẩm nữa. Mất 199662.82 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 347 sản phẩm nữa. Mất 987.19 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 346 sản phẩm nữa. Mất 1038.31 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 345 sản phẩm nữa. Mất 3660.32 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 344 sản phẩm nữa. Mất 22759.42 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 343 sản phẩm nữa. Mất 533.17 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 342 sản phẩm nữa. Mất 602.06 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 341 sản phẩm nữa. Mất 30601.67 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 340 sản phẩm nữa. Mất 8021.40 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 339 sản phẩm nữa. Mất 632.51 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 338 sản phẩm nữa. Mất 188389.31 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 337 sản phẩm nữa. Mất 1185.98 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 336 sản phẩm nữa. Mất 819.67 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 335 sản phẩm nữa. Mất 3593.98 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 334 sản phẩm nữa. Mất 22121.73 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 333 sản phẩm nữa. Mất 654.21 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 332 sản phẩm nữa. Mất 579.54 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 331 sản phẩm nữa. Mất 31418.49 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 330 sản phẩm nữa. Mất 7907.60 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 329 sản phẩm nữa. Mất 624.88 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 328 sản phẩm nữa. Mất 188422.81 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 327 sản phẩm nữa. Mất 1041.32 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 326 sản phẩm nữa. Mất 1110.15 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 325 sản phẩm nữa. Mất 3417.07 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 324 sản phẩm nữa. Mất 22205.64 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 323 sản phẩm nữa. Mất 617.20 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 322 sản phẩm nữa. Mất 595.54 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 321 sản phẩm nữa. Mất 31537.95 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 320 sản phẩm nữa. Mất 7936.37 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 319 sản phẩm nữa. Mất 645.38 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 318 sản phẩm nữa. Mất 185601.00 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 317 sản phẩm nữa. Mất 1040.47 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 316 sản phẩm nữa. Mất 967.49 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 315 sản phẩm nữa. Mất 3595.13 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 314 sản phẩm nữa. Mất 22529.81 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 313 sản phẩm nữa. Mất 585.76 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 312 sản phẩm nữa. Mất 661.35 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 311 sản phẩm nữa. Mất 30726.07 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 310 sản phẩm nữa. Mất 7674.22 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 309 sản phẩm nữa. Mất 610.82 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 308 sản phẩm nữa. Mất 189674.60 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 307 sản phẩm nữa. Mất 1150.35 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 306 sản phẩm nữa. Mất 1063.22 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 305 sản phẩm nữa. Mất 3382.92 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 304 sản phẩm nữa. Mất 22201.14 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 303 sản phẩm nữa. Mất 655.57 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 302 sản phẩm nữa. Mất 604.48 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 301 sản phẩm nữa. Mất 33051.38 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 300 sản phẩm nữa. Mất 8778.38 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 299 sản phẩm nữa. Mất 555.20 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 298 sản phẩm nữa. Mất 199598.92 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 297 sản phẩm nữa. Mất 1188.33 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 296 sản phẩm nữa. Mất 1046.57 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 295 sản phẩm nữa. Mất 3755.35 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 294 sản phẩm nữa. Mất 22316.88 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 293 sản phẩm nữa. Mất 686.29 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 292 sản phẩm nữa. Mất 561.52 mili giây
# Đã thu thập và ghi 525 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 291 sản phẩm nữa. Mất 33808.38 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 290 sản phẩm nữa. Mất 8196.89 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 289 sản phẩm nữa. Mất 544.74 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 288 sản phẩm nữa. Mất 193011.25 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 287 sản phẩm nữa. Mất 1257.43 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 286 sản phẩm nữa. Mất 1108.94 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 285 sản phẩm nữa. Mất 3542.57 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 284 sản phẩm nữa. Mất 22211.34 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 283 sản phẩm nữa. Mất 702.11 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 282 sản phẩm nữa. Mất 577.47 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 281 sản phẩm nữa. Mất 33155.31 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 280 sản phẩm nữa. Mất 7922.34 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 279 sản phẩm nữa. Mất 464.80 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 278 sản phẩm nữa. Mất 203974.94 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 277 sản phẩm nữa. Mất 1129.82 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 276 sản phẩm nữa. Mất 1077.06 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 275 sản phẩm nữa. Mất 3561.36 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 274 sản phẩm nữa. Mất 22139.92 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 273 sản phẩm nữa. Mất 671.11 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 272 sản phẩm nữa. Mất 595.26 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 271 sản phẩm nữa. Mất 31654.91 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 270 sản phẩm nữa. Mất 7944.21 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 269 sản phẩm nữa. Mất 542.09 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 268 sản phẩm nữa. Mất 184692.14 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 267 sản phẩm nữa. Mất 1133.94 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 266 sản phẩm nữa. Mất 976.09 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 265 sản phẩm nữa. Mất 3655.46 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 264 sản phẩm nữa. Mất 21471.24 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 263 sản phẩm nữa. Mất 586.41 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 262 sản phẩm nữa. Mất 633.34 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 261 sản phẩm nữa. Mất 30472.11 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 260 sản phẩm nữa. Mất 7982.09 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 259 sản phẩm nữa. Mất 586.57 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 258 sản phẩm nữa. Mất 198683.07 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 257 sản phẩm nữa. Mất 1097.11 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 256 sản phẩm nữa. Mất 902.14 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 255 sản phẩm nữa. Mất 3647.94 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 254 sản phẩm nữa. Mất 22285.62 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 253 sản phẩm nữa. Mất 605.50 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 252 sản phẩm nữa. Mất 535.13 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 251 sản phẩm nữa. Mất 31118.51 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 250 sản phẩm nữa. Mất 7796.06 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 249 sản phẩm nữa. Mất 582.95 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 248 sản phẩm nữa. Mất 198339.36 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 247 sản phẩm nữa. Mất 1022.82 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 246 sản phẩm nữa. Mất 1060.78 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 245 sản phẩm nữa. Mất 3321.28 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 244 sản phẩm nữa. Mất 21887.80 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 243 sản phẩm nữa. Mất 653.47 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 242 sản phẩm nữa. Mất 618.00 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 241 sản phẩm nữa. Mất 36851.23 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 240 sản phẩm nữa. Mất 12783.01 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 239 sản phẩm nữa. Mất 943.04 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 238 sản phẩm nữa. Mất 205252.93 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 237 sản phẩm nữa. Mất 1176.96 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 236 sản phẩm nữa. Mất 1002.22 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 235 sản phẩm nữa. Mất 3711.71 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 234 sản phẩm nữa. Mất 21452.12 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 233 sản phẩm nữa. Mất 607.93 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 232 sản phẩm nữa. Mất 538.56 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 231 sản phẩm nữa. Mất 30669.97 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 230 sản phẩm nữa. Mất 7835.56 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 229 sản phẩm nữa. Mất 545.65 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 228 sản phẩm nữa. Mất 221146.45 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 227 sản phẩm nữa. Mất 1174.54 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 226 sản phẩm nữa. Mất 1039.22 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 225 sản phẩm nữa. Mất 3401.44 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 224 sản phẩm nữa. Mất 22710.68 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 223 sản phẩm nữa. Mất 674.17 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 222 sản phẩm nữa. Mất 603.63 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 221 sản phẩm nữa. Mất 31273.27 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 220 sản phẩm nữa. Mất 7921.25 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 219 sản phẩm nữa. Mất 581.44 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 218 sản phẩm nữa. Mất 1072.91 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 217 sản phẩm nữa. Mất 6852.63 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 216 sản phẩm nữa. Mất 876.81 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 215 sản phẩm nữa. Mất 3277.43 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 214 sản phẩm nữa. Mất 21344.41 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 213 sản phẩm nữa. Mất 666.67 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 212 sản phẩm nữa. Mất 618.41 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 211 sản phẩm nữa. Mất 30267.20 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 210 sản phẩm nữa. Mất 7620.52 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 209 sản phẩm nữa. Mất 617.61 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 208 sản phẩm nữa. Mất 1107.62 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 207 sản phẩm nữa. Mất 6552.14 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 206 sản phẩm nữa. Mất 1069.46 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 205 sản phẩm nữa. Mất 3504.25 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 204 sản phẩm nữa. Mất 22469.73 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 203 sản phẩm nữa. Mất 509.29 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 202 sản phẩm nữa. Mất 617.45 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 201 sản phẩm nữa. Mất 30345.76 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 200 sản phẩm nữa. Mất 7244.81 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 199 sản phẩm nữa. Mất 635.26 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 198 sản phẩm nữa. Mất 197559.55 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 197 sản phẩm nữa. Mất 968.00 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 196 sản phẩm nữa. Mất 892.83 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 195 sản phẩm nữa. Mất 3515.11 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 194 sản phẩm nữa. Mất 22332.43 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 193 sản phẩm nữa. Mất 536.90 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 192 sản phẩm nữa. Mất 890.51 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 191 sản phẩm nữa. Mất 33085.34 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 190 sản phẩm nữa. Mất 7580.30 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 189 sản phẩm nữa. Mất 550.66 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 188 sản phẩm nữa. Mất 200463.27 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 187 sản phẩm nữa. Mất 1162.31 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 186 sản phẩm nữa. Mất 1187.51 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 185 sản phẩm nữa. Mất 3515.77 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 184 sản phẩm nữa. Mất 23100.47 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 183 sản phẩm nữa. Mất 686.22 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 182 sản phẩm nữa. Mất 684.42 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 181 sản phẩm nữa. Mất 30705.16 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 180 sản phẩm nữa. Mất 8218.63 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 179 sản phẩm nữa. Mất 601.25 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 178 sản phẩm nữa. Mất 187801.56 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 177 sản phẩm nữa. Mất 1044.58 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 176 sản phẩm nữa. Mất 900.87 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 175 sản phẩm nữa. Mất 3556.68 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 174 sản phẩm nữa. Mất 22506.12 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 173 sản phẩm nữa. Mất 596.57 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 172 sản phẩm nữa. Mất 551.82 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 171 sản phẩm nữa. Mất 31166.83 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 170 sản phẩm nữa. Mất 7560.95 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 169 sản phẩm nữa. Mất 624.44 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 168 sản phẩm nữa. Mất 1113.10 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 167 sản phẩm nữa. Mất 6726.83 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 166 sản phẩm nữa. Mất 1002.66 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 165 sản phẩm nữa. Mất 3483.87 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 164 sản phẩm nữa. Mất 21609.14 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 163 sản phẩm nữa. Mất 581.29 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 162 sản phẩm nữa. Mất 548.81 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 161 sản phẩm nữa. Mất 30213.00 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 160 sản phẩm nữa. Mất 7610.89 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 159 sản phẩm nữa. Mất 468.77 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 158 sản phẩm nữa. Mất 185392.06 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 157 sản phẩm nữa. Mất 999.68 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 156 sản phẩm nữa. Mất 831.83 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 155 sản phẩm nữa. Mất 3555.82 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 154 sản phẩm nữa. Mất 22025.19 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 153 sản phẩm nữa. Mất 634.52 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 152 sản phẩm nữa. Mất 549.66 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 151 sản phẩm nữa. Mất 29411.38 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 150 sản phẩm nữa. Mất 7974.20 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 149 sản phẩm nữa. Mất 596.29 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 148 sản phẩm nữa. Mất 183619.62 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 147 sản phẩm nữa. Mất 1075.91 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 146 sản phẩm nữa. Mất 1000.06 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 145 sản phẩm nữa. Mất 3602.91 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 144 sản phẩm nữa. Mất 21313.56 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 143 sản phẩm nữa. Mất 666.37 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 142 sản phẩm nữa. Mất 683.93 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 141 sản phẩm nữa. Mất 39855.88 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 140 sản phẩm nữa. Mất 12917.71 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 139 sản phẩm nữa. Mất 857.80 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 138 sản phẩm nữa. Mất 186726.57 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 137 sản phẩm nữa. Mất 1123.33 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 136 sản phẩm nữa. Mất 996.87 mili giây
# ...
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 133 sản phẩm nữa. Mất 714.13 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 132 sản phẩm nữa. Mất 578.94 mili giây
# Đã thu thập và ghi 529 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 131 sản phẩm nữa. Mất 32958.82 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 130 sản phẩm nữa. Mất 7298.86 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 129 sản phẩm nữa. Mất 642.57 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 128 sản phẩm nữa. Mất 217785.69 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 127 sản phẩm nữa. Mất 1231.62 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 126 sản phẩm nữa. Mất 952.20 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 125 sản phẩm nữa. Mất 3512.63 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 124 sản phẩm nữa. Mất 21895.34 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 123 sản phẩm nữa. Mất 570.16 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 122 sản phẩm nữa. Mất 619.96 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 121 sản phẩm nữa. Mất 33165.11 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 120 sản phẩm nữa. Mất 8041.55 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 119 sản phẩm nữa. Mất 560.21 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 118 sản phẩm nữa. Mất 182539.68 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 117 sản phẩm nữa. Mất 1123.89 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 116 sản phẩm nữa. Mất 912.08 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 115 sản phẩm nữa. Mất 3408.34 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 114 sản phẩm nữa. Mất 22020.94 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 113 sản phẩm nữa. Mất 677.77 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 112 sản phẩm nữa. Mất 532.93 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 111 sản phẩm nữa. Mất 30170.05 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 110 sản phẩm nữa. Mất 8168.58 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 109 sản phẩm nữa. Mất 648.49 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 108 sản phẩm nữa. Mất 223331.89 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 107 sản phẩm nữa. Mất 1003.67 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 106 sản phẩm nữa. Mất 1061.02 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 105 sản phẩm nữa. Mất 3475.76 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 104 sản phẩm nữa. Mất 28169.48 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 103 sản phẩm nữa. Mất 1114.36 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 102 sản phẩm nữa. Mất 886.63 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 101 sản phẩm nữa. Mất 34107.19 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 100 sản phẩm nữa. Mất 7912.58 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 99 sản phẩm nữa. Mất 653.66 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 98 sản phẩm nữa. Mất 186026.85 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 97 sản phẩm nữa. Mất 1202.64 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 96 sản phẩm nữa. Mất 992.24 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 95 sản phẩm nữa. Mất 3312.23 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 94 sản phẩm nữa. Mất 21890.46 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 93 sản phẩm nữa. Mất 647.61 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 92 sản phẩm nữa. Mất 526.36 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 91 sản phẩm nữa. Mất 34817.73 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 90 sản phẩm nữa. Mất 13028.38 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 89 sản phẩm nữa. Mất 925.36 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 88 sản phẩm nữa. Mất 221658.15 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 87 sản phẩm nữa. Mất 1841.88 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 86 sản phẩm nữa. Mất 1855.00 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 85 sản phẩm nữa. Mất 5847.23 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 84 sản phẩm nữa. Mất 22359.81 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 83 sản phẩm nữa. Mất 637.88 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 82 sản phẩm nữa. Mất 565.77 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 81 sản phẩm nữa. Mất 29794.40 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 80 sản phẩm nữa. Mất 7764.59 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 79 sản phẩm nữa. Mất 577.09 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 78 sản phẩm nữa. Mất 982.24 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 77 sản phẩm nữa. Mất 6601.65 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 76 sản phẩm nữa. Mất 951.63 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 75 sản phẩm nữa. Mất 3373.43 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 74 sản phẩm nữa. Mất 21719.95 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 73 sản phẩm nữa. Mất 635.72 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 72 sản phẩm nữa. Mất 456.33 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 71 sản phẩm nữa. Mất 29899.72 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 70 sản phẩm nữa. Mất 7414.44 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 69 sản phẩm nữa. Mất 688.43 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 68 sản phẩm nữa. Mất 185542.14 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 67 sản phẩm nữa. Mất 1136.75 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 66 sản phẩm nữa. Mất 1004.98 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 65 sản phẩm nữa. Mất 3275.67 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 64 sản phẩm nữa. Mất 21436.52 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 63 sản phẩm nữa. Mất 622.45 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 62 sản phẩm nữa. Mất 600.55 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 61 sản phẩm nữa. Mất 29616.77 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 60 sản phẩm nữa. Mất 8021.88 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 59 sản phẩm nữa. Mất 589.04 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 58 sản phẩm nữa. Mất 1197.02 mili giây
# Đã thu thập và ghi 124 đánh giá của sản phẩm 18682176618 tại shop 727250693. Còn 57 sản phẩm nữa. Mất 6647.36 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 56 sản phẩm nữa. Mất 1016.81 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 55 sản phẩm nữa. Mất 3568.59 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 54 sản phẩm nữa. Mất 21851.91 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 53 sản phẩm nữa. Mất 525.08 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 52 sản phẩm nữa. Mất 589.13 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 51 sản phẩm nữa. Mất 29499.08 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 50 sản phẩm nữa. Mất 7766.09 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 49 sản phẩm nữa. Mất 587.37 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 48 sản phẩm nữa. Mất 188025.35 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 47 sản phẩm nữa. Mất 1104.74 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 46 sản phẩm nữa. Mất 904.03 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 45 sản phẩm nữa. Mất 3464.71 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 44 sản phẩm nữa. Mất 22164.80 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 43 sản phẩm nữa. Mất 667.18 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 42 sản phẩm nữa. Mất 621.95 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 41 sản phẩm nữa. Mất 30483.09 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 40 sản phẩm nữa. Mất 7913.57 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 39 sản phẩm nữa. Mất 637.00 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 38 sản phẩm nữa. Mất 185840.49 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 37 sản phẩm nữa. Mất 1116.57 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 36 sản phẩm nữa. Mất 996.76 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 35 sản phẩm nữa. Mất 3406.16 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 34 sản phẩm nữa. Mất 21949.04 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 33 sản phẩm nữa. Mất 578.26 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 32 sản phẩm nữa. Mất 521.86 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 31 sản phẩm nữa. Mất 29820.58 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 30 sản phẩm nữa. Mất 7196.68 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 29 sản phẩm nữa. Mất 632.59 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 28 sản phẩm nữa. Mất 183053.65 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 27 sản phẩm nữa. Mất 1141.24 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 26 sản phẩm nữa. Mất 971.17 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 25 sản phẩm nữa. Mất 3304.73 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 24 sản phẩm nữa. Mất 22217.06 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 23 sản phẩm nữa. Mất 654.38 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 22 sản phẩm nữa. Mất 516.55 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 21 sản phẩm nữa. Mất 40660.95 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 20 sản phẩm nữa. Mất 12702.22 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 19 sản phẩm nữa. Mất 977.69 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 18 sản phẩm nữa. Mất 183688.55 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 17 sản phẩm nữa. Mất 1014.24 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 16 sản phẩm nữa. Mất 1006.74 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 15 sản phẩm nữa. Mất 3319.20 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 14 sản phẩm nữa. Mất 22972.82 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 13 sản phẩm nữa. Mất 623.29 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 12 sản phẩm nữa. Mất 577.00 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 11 sản phẩm nữa. Mất 30249.71 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 10 sản phẩm nữa. Mất 8006.64 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 19995035473 tại shop 678798230. Còn 9 sản phẩm nữa. Mất 543.46 mili giây
# Đã thu thập và ghi 3260 đánh giá của sản phẩm 3261115659 tại shop 769085. Còn 8 sản phẩm nữa. Mất 182974.14 mili giây
# Đã thu thập và ghi 15 đánh giá của sản phẩm 20883341400 tại shop 533312313. Còn 7 sản phẩm nữa. Mất 1130.08 mili giây
# Đã thu thập và ghi 8 đánh giá của sản phẩm 18583831164 tại shop 178569040. Còn 6 sản phẩm nữa. Mất 865.38 mili giây
# Đã thu thập và ghi 58 đánh giá của sản phẩm 22967626489 tại shop 985237442. Còn 5 sản phẩm nữa. Mất 3396.53 mili giây
# Đã thu thập và ghi 445 đánh giá của sản phẩm 21617915490 tại shop 788908334. Còn 4 sản phẩm nữa. Mất 21089.34 mili giây
# Đã thu thập và ghi 6 đánh giá của sản phẩm 25400385770 tại shop 677686374. Còn 3 sản phẩm nữa. Mất 682.80 mili giây
# Đã thu thập và ghi 1 đánh giá của sản phẩm 22485707071 tại shop 678666700. Còn 2 sản phẩm nữa. Mất 614.63 mili giây
# Đã thu thập và ghi 530 đánh giá của sản phẩm 22658110026 tại shop 166361135. Còn 1 sản phẩm nữa. Mất 30917.87 mili giây
# Đã thu thập và ghi 162 đánh giá của sản phẩm 23722617964 tại shop 950401869. Còn 0 sản phẩm nữa. Mất 7565.92 mili giây

# %%
import pandas as pd

# %%
data = pd.read_csv('reviews_45s.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210059 entries, 0 to 210058
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   userid       210059 non-null  int64
#  1   cmtid        210059 non-null  int64
#  2   untititle1   210059 non-null  int64
#  3   untitle2     210059 non-null  int64
#  4   mtime        210059 non-null  object
#  5   rating_star  210059 non-null  int64
#  6   comment      210059 non-null  object
# dtypes: int64(5), object(2)
# memory usage: 11.2+ MB

# %%
data['comment']
# Out:
# 0         Shop phục vụ quá tận tình, quay video chi tiết...
# 1         Đúng với mô tảok. Chất liệuok. Màu sắcok. Giao...
# 2         Khăn xinh lắm mn ơi e săn sale ở live nên là r...
# 3         Khăn len dày vừa phải, chất cũng ok. Màu đỏ đẹ...
# 4         Chất liệuvải mềm có lông lông. Đúng với mô tảđ...
#                                 ...
# 210054                                              xin nha
# 210055        Chất lượng tuyệt vời. Giá hợp lý. Đóng gói ổn
# 210056            Sản phẩm đúng mong muốn giá cả phải chăng
# 210057            Giá vừa phải nhưng dùng thì cũng tốt nha,
# 210058    Đã nhận được hàng. Đóng hộp đẹp Dùng được sẽủnghộ
# Name: comment, Length: 210059, dtype: object
